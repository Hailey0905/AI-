# %%
# Download the data and unzip it
# !gdown --fuzzy https://drive.google.com/file/d/12W3Q86wBD7K726nvHA-HWxKTtDtJGKqW/view?usp=sharing
# !unzip data.zip
# !rm data.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=12W3Q86wBD7K726nvHA-HWxKTtDtJGKqW
# From (redirected): https://drive.google.com/uc?id=12W3Q86wBD7K726nvHA-HWxKTtDtJGKqW&confirm=t&uuid=a3e371b9-a168-49c2-9342-229031c54087
# To: /content/data.zip
# 100% 124M/124M [00:01<00:00, 102MB/s]
# Archive:  data.zip
#   inflating: requirements.txt
#    creating: train_dataset/
#   inflating: train_dataset/meta.csv
#    creating: train_dataset/wavs/
#   inflating: train_dataset/wavs/1.wav
#   inflating: train_dataset/wavs/10.wav
#   inflating: train_dataset/wavs/100.wav
#   inflating: train_dataset/wavs/101.wav
#   inflating: train_dataset/wavs/102.wav
#   inflating: train_dataset/wavs/103.wav
#   inflating: train_dataset/wavs/104.wav
#   inflating: train_dataset/wavs/105.wav
#   inflating: train_dataset/wavs/106.wav
#   inflating: train_dataset/wavs/107.wav
#   inflating: train_dataset/wavs/108.wav
#   inflating: train_dataset/wavs/109.wav
#   inflating: train_dataset/wavs/11.wav
#   inflating: train_dataset/wavs/110.wav
#   inflating: train_dataset/wavs/111.wav
#   inflating: train_dataset/wavs/112.wav
#   inflating: train_dataset/wavs/113.wav
#   inflating: train_dataset/wavs/114.wav
#   inflating: train_dataset/wavs/115.wav
#   inflating: train_dataset/wavs/116.wav
#   inflating: train_dataset/wavs/117.wav
#   inflating: train_dataset/wavs/118.wav
#   inflating: train_dataset/wavs/119.wav
#   inflating: train_dataset/wavs/12.wav
#   inflating: train_dataset/wavs/120.wav
#   inflating: train_dataset/wavs/121.wav
#   inflating: train_dataset/wavs/122.wav
#   inflating: train_dataset/wavs/123.wav
#   inflating: train_dataset/wavs/124.wav
#   inflating: train_dataset/wavs/125.wav
#   inflating: train_dataset/wavs/126.wav
#   inflating: train_dataset/wavs/127.wav
#   inflating: train_dataset/wavs/128.wav
#   inflating: train_dataset/wavs/129.wav
#   inflating: train_dataset/wavs/13.wav
#   inflating: train_dataset/wavs/130.wav
#   inflating: train_dataset/wavs/131.wav
#   inflating: train_dataset/wavs/132.wav
#   inflating: train_dataset/wavs/133.wav
#   inflating: train_dataset/wavs/134.wav
#   inflating: train_dataset/wavs/135.wav
#   inflating: train_dataset/wavs/136.wav
#   inflating: train_dataset/wavs/137.wav
#   inflating: train_dataset/wavs/138.wav
#   inflating: train_dataset/wavs/139.wav
#   inflating: train_dataset/wavs/14.wav
#   inflating: train_dataset/wavs/140.wav
#   inflating: train_dataset/wavs/141.wav
#   inflating: train_dataset/wavs/142.wav
#   inflating: train_dataset/wavs/143.wav
#   inflating: train_dataset/wavs/144.wav
#   inflating: train_dataset/wavs/145.wav
#   inflating: train_dataset/wavs/146.wav
#   inflating: train_dataset/wavs/147.wav
#   inflating: train_dataset/wavs/148.wav
#   inflating: train_dataset/wavs/149.wav
#   inflating: train_dataset/wavs/15.wav
#   inflating: train_dataset/wavs/150.wav
#   inflating: train_dataset/wavs/151.wav
#   inflating: train_dataset/wavs/152.wav
#   inflating: train_dataset/wavs/153.wav
#   inflating: train_dataset/wavs/154.wav
#   inflating: train_dataset/wavs/155.wav
#   inflating: train_dataset/wavs/156.wav
#   inflating: train_dataset/wavs/157.wav
#   inflating: train_dataset/wavs/158.wav
#   inflating: train_dataset/wavs/159.wav
#   inflating: train_dataset/wavs/16.wav
#   inflating: train_dataset/wavs/160.wav
#   inflating: train_dataset/wavs/161.wav
#   inflating: train_dataset/wavs/162.wav
#   inflating: train_dataset/wavs/163.wav
#   inflating: train_dataset/wavs/164.wav
#   inflating: train_dataset/wavs/165.wav
#   inflating: train_dataset/wavs/166.wav
#   inflating: train_dataset/wavs/167.wav
#   inflating: train_dataset/wavs/168.wav
#   inflating: train_dataset/wavs/169.wav
#   inflating: train_dataset/wavs/17.wav
#   inflating: train_dataset/wavs/170.wav
#   inflating: train_dataset/wavs/171.wav
#   inflating: train_dataset/wavs/172.wav
#   inflating: train_dataset/wavs/173.wav
#   inflating: train_dataset/wavs/174.wav
#   inflating: train_dataset/wavs/175.wav
#   inflating: train_dataset/wavs/176.wav
#   inflating: train_dataset/wavs/177.wav
#   inflating: train_dataset/wavs/178.wav
#   inflating: train_dataset/wavs/179.wav
#   inflating: train_dataset/wavs/18.wav
#   inflating: train_dataset/wavs/180.wav
#   inflating: train_dataset/wavs/181.wav
#   inflating: train_dataset/wavs/182.wav
#   inflating: train_dataset/wavs/183.wav
#   inflating: train_dataset/wavs/184.wav
#   inflating: train_dataset/wavs/185.wav
#   inflating: train_dataset/wavs/186.wav
#   inflating: train_dataset/wavs/187.wav
#   inflating: train_dataset/wavs/188.wav
#   inflating: train_dataset/wavs/189.wav
#   inflating: train_dataset/wavs/19.wav
#   inflating: train_dataset/wavs/190.wav
#   inflating: train_dataset/wavs/191.wav
#   inflating: train_dataset/wavs/192.wav
#   inflating: train_dataset/wavs/193.wav
#   inflating: train_dataset/wavs/194.wav
#   inflating: train_dataset/wavs/195.wav
#   inflating: train_dataset/wavs/196.wav
#   inflating: train_dataset/wavs/197.wav
#   inflating: train_dataset/wavs/198.wav
#   inflating: train_dataset/wavs/199.wav
#   inflating: train_dataset/wavs/2.wav
#   inflating: train_dataset/wavs/20.wav
#   inflating: train_dataset/wavs/200.wav
#   inflating: train_dataset/wavs/201.wav
#   inflating: train_dataset/wavs/202.wav
#   inflating: train_dataset/wavs/203.wav
#   inflating: train_dataset/wavs/204.wav
#   inflating: train_dataset/wavs/205.wav
#   inflating: train_dataset/wavs/206.wav
#   inflating: train_dataset/wavs/207.wav
#   inflating: train_dataset/wavs/208.wav
#   inflating: train_dataset/wavs/209.wav
#   inflating: train_dataset/wavs/21.wav
#   inflating: train_dataset/wavs/210.wav
#   inflating: train_dataset/wavs/211.wav
#   inflating: train_dataset/wavs/212.wav
#   inflating: train_dataset/wavs/213.wav
#   inflating: train_dataset/wavs/214.wav
#   inflating: train_dataset/wavs/215.wav
#   inflating: train_dataset/wavs/216.wav
#   inflating: train_dataset/wavs/217.wav
#   inflating: train_dataset/wavs/218.wav
#   inflating: train_dataset/wavs/219.wav
#   inflating: train_dataset/wavs/22.wav
#   inflating: train_dataset/wavs/220.wav
#   inflating: train_dataset/wavs/221.wav
#   inflating: train_dataset/wavs/222.wav
#   inflating: train_dataset/wavs/223.wav
#   inflating: train_dataset/wavs/224.wav
#   inflating: train_dataset/wavs/225.wav
#   inflating: train_dataset/wavs/226.wav
#   inflating: train_dataset/wavs/227.wav
#   inflating: train_dataset/wavs/228.wav
#   inflating: train_dataset/wavs/229.wav
#   inflating: train_dataset/wavs/23.wav
#   inflating: train_dataset/wavs/230.wav
#   inflating: train_dataset/wavs/231.wav
#   inflating: train_dataset/wavs/232.wav
#   inflating: train_dataset/wavs/233.wav
#   inflating: train_dataset/wavs/234.wav
#   inflating: train_dataset/wavs/235.wav
#   inflating: train_dataset/wavs/236.wav
#   inflating: train_dataset/wavs/237.wav
#   inflating: train_dataset/wavs/238.wav
#   inflating: train_dataset/wavs/239.wav
#   inflating: train_dataset/wavs/24.wav
#   inflating: train_dataset/wavs/240.wav
#   inflating: train_dataset/wavs/241.wav
#   inflating: train_dataset/wavs/242.wav
#   inflating: train_dataset/wavs/243.wav
#   inflating: train_dataset/wavs/244.wav
#   inflating: train_dataset/wavs/245.wav
#   inflating: train_dataset/wavs/246.wav
#   inflating: train_dataset/wavs/247.wav
#   inflating: train_dataset/wavs/248.wav
#   inflating: train_dataset/wavs/249.wav
#   inflating: train_dataset/wavs/25.wav
#   inflating: train_dataset/wavs/250.wav
#   inflating: train_dataset/wavs/251.wav
#   inflating: train_dataset/wavs/252.wav
#   inflating: train_dataset/wavs/253.wav
#   inflating: train_dataset/wavs/254.wav
#   inflating: train_dataset/wavs/255.wav
#   inflating: train_dataset/wavs/256.wav
#   inflating: train_dataset/wavs/257.wav
#   inflating: train_dataset/wavs/258.wav
#   inflating: train_dataset/wavs/259.wav
#   inflating: train_dataset/wavs/26.wav
#   inflating: train_dataset/wavs/260.wav
#   inflating: train_dataset/wavs/261.wav
#   inflating: train_dataset/wavs/262.wav
#   inflating: train_dataset/wavs/263.wav
#   inflating: train_dataset/wavs/264.wav
#   inflating: train_dataset/wavs/265.wav
#   inflating: train_dataset/wavs/266.wav
#   inflating: train_dataset/wavs/267.wav
#   inflating: train_dataset/wavs/268.wav
#   inflating: train_dataset/wavs/269.wav
#   inflating: train_dataset/wavs/27.wav
#   inflating: train_dataset/wavs/270.wav
#   inflating: train_dataset/wavs/271.wav
#   inflating: train_dataset/wavs/272.wav
#   inflating: train_dataset/wavs/273.wav
#   inflating: train_dataset/wavs/274.wav
#   inflating: train_dataset/wavs/275.wav
#   inflating: train_dataset/wavs/276.wav
#   inflating: train_dataset/wavs/277.wav
#   inflating: train_dataset/wavs/278.wav
#   inflating: train_dataset/wavs/279.wav
#   inflating: train_dataset/wavs/28.wav
#   inflating: train_dataset/wavs/280.wav
#   inflating: train_dataset/wavs/281.wav
#   inflating: train_dataset/wavs/282.wav
#   inflating: train_dataset/wavs/283.wav
#   inflating: train_dataset/wavs/284.wav
#   inflating: train_dataset/wavs/285.wav
#   inflating: train_dataset/wavs/286.wav
#   inflating: train_dataset/wavs/287.wav
#   inflating: train_dataset/wavs/288.wav
#   inflating: train_dataset/wavs/289.wav
#   inflating: train_dataset/wavs/29.wav
#   inflating: train_dataset/wavs/290.wav
#   inflating: train_dataset/wavs/291.wav
#   inflating: train_dataset/wavs/292.wav
#   inflating: train_dataset/wavs/293.wav
#   inflating: train_dataset/wavs/294.wav
#   inflating: train_dataset/wavs/295.wav
#   inflating: train_dataset/wavs/296.wav
#   inflating: train_dataset/wavs/297.wav
#   inflating: train_dataset/wavs/298.wav
#   inflating: train_dataset/wavs/299.wav
#   inflating: train_dataset/wavs/3.wav
#   inflating: train_dataset/wavs/30.wav
#   inflating: train_dataset/wavs/300.wav
#   inflating: train_dataset/wavs/301.wav
#   inflating: train_dataset/wavs/302.wav
#   inflating: train_dataset/wavs/303.wav
#   inflating: train_dataset/wavs/304.wav
#   inflating: train_dataset/wavs/305.wav
#   inflating: train_dataset/wavs/306.wav
#   inflating: train_dataset/wavs/307.wav
#   inflating: train_dataset/wavs/308.wav
#   inflating: train_dataset/wavs/309.wav
#   inflating: train_dataset/wavs/31.wav
#   inflating: train_dataset/wavs/310.wav
#   inflating: train_dataset/wavs/311.wav
#   inflating: train_dataset/wavs/312.wav
#   inflating: train_dataset/wavs/313.wav
#   inflating: train_dataset/wavs/314.wav
#   inflating: train_dataset/wavs/315.wav
#   inflating: train_dataset/wavs/316.wav
#   inflating: train_dataset/wavs/317.wav
#   inflating: train_dataset/wavs/318.wav
#   inflating: train_dataset/wavs/319.wav
#   inflating: train_dataset/wavs/32.wav
#   inflating: train_dataset/wavs/320.wav
#   inflating: train_dataset/wavs/321.wav
#   inflating: train_dataset/wavs/322.wav
#   inflating: train_dataset/wavs/323.wav
#   inflating: train_dataset/wavs/324.wav
#   inflating: train_dataset/wavs/325.wav
#   inflating: train_dataset/wavs/326.wav
#   inflating: train_dataset/wavs/327.wav
#   inflating: train_dataset/wavs/328.wav
#   inflating: train_dataset/wavs/329.wav
#   inflating: train_dataset/wavs/33.wav
#   inflating: train_dataset/wavs/330.wav
#   inflating: train_dataset/wavs/331.wav
#   inflating: train_dataset/wavs/332.wav
#   inflating: train_dataset/wavs/333.wav
#   inflating: train_dataset/wavs/334.wav
#   inflating: train_dataset/wavs/335.wav
#   inflating: train_dataset/wavs/336.wav
#   inflating: train_dataset/wavs/337.wav
#   inflating: train_dataset/wavs/338.wav
#   inflating: train_dataset/wavs/339.wav
#   inflating: train_dataset/wavs/34.wav
#   inflating: train_dataset/wavs/340.wav
#   inflating: train_dataset/wavs/341.wav
#   inflating: train_dataset/wavs/342.wav
#   inflating: train_dataset/wavs/343.wav
#   inflating: train_dataset/wavs/344.wav
#   inflating: train_dataset/wavs/345.wav
#   inflating: train_dataset/wavs/346.wav
#   inflating: train_dataset/wavs/347.wav
#   inflating: train_dataset/wavs/348.wav
#   inflating: train_dataset/wavs/349.wav
#   inflating: train_dataset/wavs/35.wav
#   inflating: train_dataset/wavs/350.wav
#   inflating: train_dataset/wavs/351.wav
#   inflating: train_dataset/wavs/352.wav
#   inflating: train_dataset/wavs/353.wav
#   inflating: train_dataset/wavs/354.wav
#   inflating: train_dataset/wavs/355.wav
#   inflating: train_dataset/wavs/356.wav
#   inflating: train_dataset/wavs/357.wav
#   inflating: train_dataset/wavs/358.wav
#   inflating: train_dataset/wavs/359.wav
#   inflating: train_dataset/wavs/36.wav
#   inflating: train_dataset/wavs/360.wav
#   inflating: train_dataset/wavs/361.wav
#   inflating: train_dataset/wavs/362.wav
#   inflating: train_dataset/wavs/363.wav
#   inflating: train_dataset/wavs/364.wav
#   inflating: train_dataset/wavs/365.wav
#   inflating: train_dataset/wavs/366.wav
#   inflating: train_dataset/wavs/367.wav
#   inflating: train_dataset/wavs/368.wav
#   inflating: train_dataset/wavs/369.wav
#   inflating: train_dataset/wavs/37.wav
#   inflating: train_dataset/wavs/370.wav
#   inflating: train_dataset/wavs/371.wav
#   inflating: train_dataset/wavs/372.wav
#   inflating: train_dataset/wavs/373.wav
#   inflating: train_dataset/wavs/374.wav
#   inflating: train_dataset/wavs/375.wav
#   inflating: train_dataset/wavs/376.wav
#   inflating: train_dataset/wavs/377.wav
#   inflating: train_dataset/wavs/378.wav
#   inflating: train_dataset/wavs/379.wav
#   inflating: train_dataset/wavs/38.wav
#   inflating: train_dataset/wavs/380.wav
#   inflating: train_dataset/wavs/381.wav
#   inflating: train_dataset/wavs/382.wav
#   inflating: train_dataset/wavs/383.wav
#   inflating: train_dataset/wavs/384.wav
#   inflating: train_dataset/wavs/385.wav
#   inflating: train_dataset/wavs/386.wav
#   inflating: train_dataset/wavs/387.wav
#   inflating: train_dataset/wavs/388.wav
#   inflating: train_dataset/wavs/389.wav
#   inflating: train_dataset/wavs/39.wav
#   inflating: train_dataset/wavs/390.wav
#   inflating: train_dataset/wavs/391.wav
#   inflating: train_dataset/wavs/392.wav
#   inflating: train_dataset/wavs/393.wav
#   inflating: train_dataset/wavs/394.wav
#   inflating: train_dataset/wavs/395.wav
#   inflating: train_dataset/wavs/396.wav
#   inflating: train_dataset/wavs/397.wav
#   inflating: train_dataset/wavs/398.wav
#   inflating: train_dataset/wavs/399.wav
#   inflating: train_dataset/wavs/4.wav
#   inflating: train_dataset/wavs/40.wav
#   inflating: train_dataset/wavs/400.wav
#   inflating: train_dataset/wavs/401.wav
#   inflating: train_dataset/wavs/402.wav
#   inflating: train_dataset/wavs/403.wav
#   inflating: train_dataset/wavs/404.wav
#   inflating: train_dataset/wavs/405.wav
#   inflating: train_dataset/wavs/406.wav
#   inflating: train_dataset/wavs/407.wav
#   inflating: train_dataset/wavs/408.wav
#   inflating: train_dataset/wavs/409.wav
#   inflating: train_dataset/wavs/41.wav
#   inflating: train_dataset/wavs/410.wav
#   inflating: train_dataset/wavs/411.wav
#   inflating: train_dataset/wavs/412.wav
#   inflating: train_dataset/wavs/413.wav
#   inflating: train_dataset/wavs/414.wav
#   inflating: train_dataset/wavs/415.wav
#   inflating: train_dataset/wavs/416.wav
#   inflating: train_dataset/wavs/417.wav
#   inflating: train_dataset/wavs/418.wav
#   inflating: train_dataset/wavs/419.wav
#   inflating: train_dataset/wavs/42.wav
#   inflating: train_dataset/wavs/420.wav
#   inflating: train_dataset/wavs/421.wav
#   inflating: train_dataset/wavs/422.wav
#   inflating: train_dataset/wavs/423.wav
#   inflating: train_dataset/wavs/424.wav
#   inflating: train_dataset/wavs/425.wav
#   inflating: train_dataset/wavs/426.wav
#   inflating: train_dataset/wavs/427.wav
#   inflating: train_dataset/wavs/428.wav
#   inflating: train_dataset/wavs/429.wav
#   inflating: train_dataset/wavs/43.wav
#   inflating: train_dataset/wavs/430.wav
#   inflating: train_dataset/wavs/431.wav
#   inflating: train_dataset/wavs/432.wav
#   inflating: train_dataset/wavs/433.wav
#   inflating: train_dataset/wavs/434.wav
#   inflating: train_dataset/wavs/435.wav
#   inflating: train_dataset/wavs/436.wav
#   inflating: train_dataset/wavs/437.wav
#   inflating: train_dataset/wavs/438.wav
#   inflating: train_dataset/wavs/439.wav
#   inflating: train_dataset/wavs/44.wav
#   inflating: train_dataset/wavs/440.wav
#   inflating: train_dataset/wavs/441.wav
#   inflating: train_dataset/wavs/442.wav
#   inflating: train_dataset/wavs/443.wav
#   inflating: train_dataset/wavs/444.wav
#   inflating: train_dataset/wavs/445.wav
#   inflating: train_dataset/wavs/446.wav
#   inflating: train_dataset/wavs/447.wav
#   inflating: train_dataset/wavs/448.wav
#   inflating: train_dataset/wavs/449.wav
#   inflating: train_dataset/wavs/45.wav
#   inflating: train_dataset/wavs/450.wav
#   inflating: train_dataset/wavs/451.wav
#   inflating: train_dataset/wavs/452.wav
#   inflating: train_dataset/wavs/453.wav
#   inflating: train_dataset/wavs/454.wav
#   inflating: train_dataset/wavs/455.wav
#   inflating: train_dataset/wavs/456.wav
#   inflating: train_dataset/wavs/457.wav
#   inflating: train_dataset/wavs/458.wav
#   inflating: train_dataset/wavs/459.wav
#   inflating: train_dataset/wavs/46.wav
#   inflating: train_dataset/wavs/460.wav
#   inflating: train_dataset/wavs/461.wav
#   inflating: train_dataset/wavs/462.wav
#   inflating: train_dataset/wavs/463.wav
#   inflating: train_dataset/wavs/464.wav
#   inflating: train_dataset/wavs/465.wav
#   inflating: train_dataset/wavs/466.wav
#   inflating: train_dataset/wavs/467.wav
#   inflating: train_dataset/wavs/468.wav
#   inflating: train_dataset/wavs/469.wav
#   inflating: train_dataset/wavs/47.wav
#   inflating: train_dataset/wavs/470.wav
#   inflating: train_dataset/wavs/471.wav
#   inflating: train_dataset/wavs/472.wav
#   inflating: train_dataset/wavs/473.wav
#   inflating: train_dataset/wavs/474.wav
#   inflating: train_dataset/wavs/475.wav
#   inflating: train_dataset/wavs/476.wav
#   inflating: train_dataset/wavs/477.wav
#   inflating: train_dataset/wavs/478.wav
#   inflating: train_dataset/wavs/479.wav
#   inflating: train_dataset/wavs/48.wav
#   inflating: train_dataset/wavs/480.wav
#   inflating: train_dataset/wavs/481.wav
#   inflating: train_dataset/wavs/482.wav
#   inflating: train_dataset/wavs/483.wav
#   inflating: train_dataset/wavs/484.wav
#   inflating: train_dataset/wavs/485.wav
#   inflating: train_dataset/wavs/486.wav
#   inflating: train_dataset/wavs/487.wav
#   inflating: train_dataset/wavs/488.wav
#   inflating: train_dataset/wavs/489.wav
#   inflating: train_dataset/wavs/49.wav
#   inflating: train_dataset/wavs/490.wav
#   inflating: train_dataset/wavs/491.wav
#   inflating: train_dataset/wavs/492.wav
#   inflating: train_dataset/wavs/493.wav
#   inflating: train_dataset/wavs/494.wav
#   inflating: train_dataset/wavs/495.wav
#   inflating: train_dataset/wavs/496.wav
#   inflating: train_dataset/wavs/497.wav
#   inflating: train_dataset/wavs/498.wav
#   inflating: train_dataset/wavs/499.wav
#   inflating: train_dataset/wavs/5.wav
#   inflating: train_dataset/wavs/50.wav
#   inflating: train_dataset/wavs/500.wav
#   inflating: train_dataset/wavs/51.wav
#   inflating: train_dataset/wavs/52.wav
#   inflating: train_dataset/wavs/53.wav
#   inflating: train_dataset/wavs/54.wav
#   inflating: train_dataset/wavs/55.wav
#   inflating: train_dataset/wavs/56.wav
#   inflating: train_dataset/wavs/57.wav
#   inflating: train_dataset/wavs/58.wav
#   inflating: train_dataset/wavs/59.wav
#   inflating: train_dataset/wavs/6.wav
#   inflating: train_dataset/wavs/60.wav
#   inflating: train_dataset/wavs/61.wav
#   inflating: train_dataset/wavs/62.wav
#   inflating: train_dataset/wavs/63.wav
#   inflating: train_dataset/wavs/64.wav
#   inflating: train_dataset/wavs/65.wav
#   inflating: train_dataset/wavs/66.wav
#   inflating: train_dataset/wavs/67.wav
#   inflating: train_dataset/wavs/68.wav
#   inflating: train_dataset/wavs/69.wav
#   inflating: train_dataset/wavs/7.wav
#   inflating: train_dataset/wavs/70.wav
#   inflating: train_dataset/wavs/71.wav
#   inflating: train_dataset/wavs/72.wav
#   inflating: train_dataset/wavs/73.wav
#   inflating: train_dataset/wavs/74.wav
#   inflating: train_dataset/wavs/75.wav
#   inflating: train_dataset/wavs/76.wav
#   inflating: train_dataset/wavs/77.wav
#   inflating: train_dataset/wavs/78.wav
#   inflating: train_dataset/wavs/79.wav
#   inflating: train_dataset/wavs/8.wav
#   inflating: train_dataset/wavs/80.wav
#   inflating: train_dataset/wavs/81.wav
#   inflating: train_dataset/wavs/82.wav
#   inflating: train_dataset/wavs/83.wav
#   inflating: train_dataset/wavs/84.wav
#   inflating: train_dataset/wavs/85.wav
#   inflating: train_dataset/wavs/86.wav
#   inflating: train_dataset/wavs/87.wav
#   inflating: train_dataset/wavs/88.wav
#   inflating: train_dataset/wavs/89.wav
#   inflating: train_dataset/wavs/9.wav
#   inflating: train_dataset/wavs/90.wav
#   inflating: train_dataset/wavs/91.wav
#   inflating: train_dataset/wavs/92.wav
#   inflating: train_dataset/wavs/93.wav
#   inflating: train_dataset/wavs/94.wav
#   inflating: train_dataset/wavs/95.wav
#   inflating: train_dataset/wavs/96.wav
#   inflating: train_dataset/wavs/97.wav
#   inflating: train_dataset/wavs/98.wav
#   inflating: train_dataset/wavs/99.wav

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-
# 127800K .......... .......... .......... .......... .......... 99% 47.0M 0s
# 127850K .......... .......... .......... .......... .......... 99% 51.4M 0s
# 127900K .......... .......... .......... .......... .......... 99%  139M 0s
# 127950K .......... .......... .......... .......... .......... 99%  200M 0s
# 128000K .......... .......... .......... .......... .......... 99%  275M 0s
# 128050K .......... .......... .......... .......... .......... 99% 55.0M 0s
# 128100K .......... .......... .......... .......... .......... 99% 58.6M 0s
# 128150K .......... .......... .......... .......... .......... 99% 28.3M 0s
# 128200K .......... .......... .......... .......... .......... 99% 80.6M 0s
# 128250K .......... .......... .......... .......... .......... 99%  232M 0s
# 128300K .......... .......... .......... .......... .......... 99% 77.0M 0s
# 128350K .......... .......... .......... .......... .......... 99%  198M 0s
# 128400K .......... .......... .......... .......... .......... 99%  219M 0s
# 128450K .......... .......... .......... .......... .......... 99%  224M 0s
# 128500K .......... .......... .......... .......... .......... 99%  239M 0s
# 128550K .......... .......... .......... .......... .......... 99%  207M 0s
# 128600K .......... .......... .......... .......... .......... 99%  125M 0s
# 128650K .......... .......... .......... .......... .......... 99%  209M 0s
# 128700K .......... .......... .......... .......... .......... 99%  189M 0s
# 128750K ....                                                  100%  101M=1.0s
#
# 2024-12-08 09:49:09 (124 MB/s) - ‘Miniconda3-py38_23.11.0-2-Linux-x86_64.sh’ saved [131844786/131844786]
#
# Extracting : cryptography-41.0.7-py38hdda0065_0.conda:  99%|█████████▊| 70/71 [00:04<00:00,  6.57it/s]

# %%
# %%bash
# conda install --channel defaults conda python=3.8 --yes
# conda update --channel defaults --all --yes
# conda install conda-forge::mamba --yes
# mamba install --file requirements.txt -c pytorch -c defaults -c anaconda -c conda-forge --yes
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd3eb1b0_0          47 KB
#     ca-certificates-2024.11.26 |       h06a4308_0         131 KB
#     certifi-2024.8.30          |   py38h06a4308_0         162 KB
#     conda-24.9.2               |   py38h06a4308_0         910 KB
#     frozendict-2.4.2           |   py38h5eee18b_0          55 KB
#     openssl-3.0.15             |       h5eee18b_0         5.2 MB
#     python-3.8.20              |       he870216_0        23.8 MB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     ------------------------------------------------------------
#                                            Total:        35.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   frozendict         pkgs/main/linux-64::frozendict-2.4.2-py38h5eee18b_0
#
# The following packages will be UPDATED:
#
#   archspec                               0.2.1-pyhd3eb1b0_0 --> 0.2.3-pyhd3eb1b0_0
#   ca-certificates                     2023.12.12-h06a4308_0 --> 2024.11.26-h06a4308_0
#   certifi                         2023.11.17-py38h06a4308_0 --> 2024.8.30-py38h06a4308_0
#   conda                              23.11.0-py38h06a4308_0 --> 24.9.2-py38h06a4308_0
#   openssl                                 3.0.12-h7f8727e_0 --> 3.0.15-h5eee18b_0
#   python                                  3.8.18-h955ad1f_0 --> 3.8.20-he870216_0
#   sqlite                                  3.41.2-h5eee18b_0 --> 3.45.3-h5eee18b_0
#   tk                                      8.6.12-h1ccaba5_0 --> 8.6.14-h39e8969_0
#   xz                                       5.4.5-h5eee18b_0 --> 5.4.6-h5eee18b_1
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.0.9        |   py38h6a678d5_8         356 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     cffi-1.17.1                |   py38h1fdaa30_0         253 KB
#     charset-normalizer-3.3.2   |     pyhd3eb1b0_0          44 KB
#     conda
#   ld_impl_linux-64                          2.38-h1181459_1 --> 2.40-h12ee557_0
#   libarchive                               3.6.2-h6ac8c49_2 --> 3.7.4-hfab0078_0
#   libcurl                                  8.4.0-h251f7ec_1 --> 8.9.1-h251f7ec_0
#   libffi                                   3.4.4-h6a678d5_0 --> 3.4.4-h6a678d5_1
#   libmamba                                 1.5.3-haf1ee3a_0 --> 1.5.8-hfe524e5_3
#   libmambapy                           1.5.3-py38h2dafd23_0 --> 1.5.8-py38h2dafd23_3
#   libsolv                                 0.7.24-he621ea3_0 --> 0.7.24-he621ea3_1
#   libssh2                                 1.10.0-hdbd6064_2 --> 1.11.1-h251f7ec_0
#   libxml2                                 2.10.4-hf1b16e4_1 --> 2.13.5-hfdd30dd_0
#   lz4-c                                    1.9.4-h6a678d5_0 --> 1.9.4-h6a678d5_1
#   menuinst                             2.0.1-py38h06a4308_1 --> 2.2.0-py38h06a4308_0
#   packaging                             23.1-py38h06a4308_0 --> 24.1-py38h06a4308_0
#   pcre2                                    10.42-hebb0a14_0 --> 10.42-hebb0a14_1
#   pip                                 23.3.1-py38h06a4308_0 --> 24.2-py38h06a4308_0
#   pycosat                              0.6.6-py38h5eee18b_0 --> 0.6.6-py38h5eee18b_1
#   pyopenssl                           23.2.0-py38h06a4308_0 --> 24.2.1-py38h06a4308_0
#   reproc                                  14.2.4-h295c915_1 --> 14.2.4-h6a678d5_2
#   reproc-cpp                              14.2.4-h295c915_1 --> 14.2.4-h6a678d5_2
#   requests                            2.31.0-py38h06a4308_0 --> 2.32.3-py38h06a4308_0
#   ruamel.yaml                        0.17.21-py38h5eee18b_0 --> 0.18.6-py38h5eee18b_0
#   ruamel.yaml.clib                     0.2.6-py38h5eee18b_1 --> 0.2.8-py38h5eee18b_0
#   setuptools                          68.2.2-py38h06a4308_0 --> 75.1.0-py38h06a4308_0
#   tqdm                                4.65.0-py38hb070fc8_0 --> 4.66.5-py38h2f386ee_0
#   urllib3                            1.26.18-py38h06a4308_0 --> 2.2.3-py38h06a4308_0
#   wheel                               0.41.2-py38h06a4308_0 --> 0.44.0-py38h06a4308_0
#   yaml-cpp                                 0.8.0-h6a678d5_0 --> 0.8.0-h6a678d5_1
#   zlib                                    1.2.13-h5eee18b_0 --> 1.2.13-h5eee18b_1
#   zstandard                           0.19.0-py38h5eee18b_0 --> 0.23.0-py38h2c38b39_0
#   zstd                                     1.5.5-hc292b87_0 --> 1.5.6-hc292b87_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda-forge::mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     conda-24.7.1               |   py38h06a4308_0         954 KB
#     fmt-10.2.1                 |       h00ab1b0_0         189 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_1          53 KB  conda-forge
#     libgomp-14.2.0             |       h77fa898_1         450 KB  conda-forge
#     libmamba-1.5.8             |       had39da4_0         1.6 MB  conda-forge
#     libmambapy-1.5.8           |   py38h5cd715c_0         303 KB  conda-forge
#     libstdcxx-14.2.0           |       hc0a3c3a_1         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_1          53 KB  conda-forge
#     mamba-1.5.8                |   py38haad2881_0          50 KB  conda-forge
#     openssl-3.4.0              |       hb9d3cd8_0         2.8 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h77fa898_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-hc0a3c3a_1
#   mamba              conda-forge/linux-64::mamba-1.5.8-py38haad2881_0
#   python_abi         conda-forge/linux-64::python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   fmt                       pkgs/main::fmt-9.1.0-hdb19cb5_1 --> conda-forge::fmt-10.2.1-h00ab1b0_0
#   libgcc-ng          pkgs/main::libgcc-ng-11.2.0-h1234567_1 --> conda-forge::libgcc-ng-14.2.0-h69a702a_1
#   libgomp              pkgs/main::libgomp-11.2.0-h1234567_1 --> conda-forge::libgomp-14.2.0-h77fa898_1
#   libstdcxx-ng       pkgs/main::libstdcxx-ng-11.2.0-h12345~ --> conda-forge::libstdcxx-ng-14.2.0-h4852527_1
#   openssl              pkgs/main::openssl-3.0.15-h5eee18b_0 --> conda-forge::openssl-3.4.0-hb9d3cd8_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   _libgcc_mutex           pkgs/main::_libgcc_mutex-0.1-main --> conda-forge::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex          pkgs/main::_openmp_mutex-5.1-1_gnu --> conda-forge::_openmp_mutex-4.5-2_gnu
#   libmamba             pkgs/main::libmamba-1.5.8-hfe524e5_3 --> conda-forge::libmamba-1.5.8-had39da4_0
#   libmambapy         pkgs/main::libmambapy-1.5.8-py38h2daf~ --> conda-forge::libmambapy-1.5.8-py38h5cd715c_0
#
# The following packages will be DOWNGRADED:
#
#   conda                               24.9.2-py38h06a4308_0 --> 24.7.1-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - pytorch[version='>=1.12.1,<2']
#    - numpy[version='>=1.22.0']
#    - scipy[version='>=1.4.1']
#    - librosa[version='>=0.10.0']
#    - inflect[version='>=0.2.5']
#    - numba[version='>=0.54.0']
#    - pysoundfile==0.12.1
#    - unidecode
#    - tqdm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                     Version  Build           Channel           Size
# ───────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────
#
#   + pytorch-mutex                 1.0  cpu             pytorch            3kB
#   + unidecode                   1.3.8  py38h06a4308_0  pkgs/main        283kB
#   + joblib                      1.4.2  py38h06a4308_0  pkgs/main        406kB
#   + lazy_loader                   0.4  py38h06a4308_0  pkgs/main         21kB
#   + msgpack-python              1.0.3  py38hd09550d_0  pkgs/main         85kB
#   + pooch                       1.7.0  py38h06a4308_0  pkgs/main         83kB
#   + typing_extensions          4.11.0  py38h06a4308_0  pkgs/main         60kB
#   + lame                        3.100  h7b6447c_0      pkgs/main        331kB
#   + libogg                      1.3.5  h27cfd23_1      pkgs/main        204kB
#   + libopus                     1.3.1  h5eee18b_1      pkgs/main        354kB
#   + blas                          1.0  mkl             pkgs/main          6kB
#   + libgfortran5               11.2.0  h1234567_1      pkgs/main          2MB
#   + threadpoolctl               3.5.0  py38h2f386ee_0  pkgs/main         43kB
#   + tbb                      2021.8.0  hdb19cb5_0      pkgs/main          2MB
#   + kiwisolver                  1.4.4  py38h6a678d5_0  pkgs/main         78kB
#   + pyparsing                   3.0.9  py38h06a4308_0  pkgs/main        155kB
#   + zipp                       3.20.2  py38h06a4308_0  pkgs/main         26kB
#   + unicodedata2               15.1.0  py38h5eee18b_0  pkgs/main        537kB
#   + gmp                         6.2.1  h295c915_3      pkgs/main        557kB
#   + libiconv                     1.16  h5eee18b_3      pkgs/main        777kB
#   + openh264                    2.1.1  h4ff587b_0      pkgs/main        728kB
#   + jpeg                           9e  h5eee18b_3      pkgs/main        268kB
#   + libwebp-base                1.3.2  h5eee18b_1      pkgs/main        435kB
#   + lerc                          3.0  h295c915_0      pkgs/main        201kB
#   + libdeflate                   1.17  h5eee18b_1      pkgs/main         66kB
#   + libbrotlicommon             1.0.9  h5eee18b_8      pkgs/main         70kB
#   + libtasn1                   4.19.0  h5eee18b_0      pkgs/main         65kB
#   + libunistring               0.9.10  h27cfd23_0      pkgs/main        548kB
#   + typing-extensions          4.11.0  py38h06a4308_0  pkgs/main          9kB
#   + libvorbis                   1.3.7  h7b6447c_0      pkgs/main        408kB
#   + libgfortran-ng             11.2.0  h00389a5_1      pkgs/main         20kB
#   + importlib_resources         6.4.0  py38h06a4308_0  pkgs/main         62kB
#   + importlib-metadata          7.0.1  py38h06a4308_0  pkgs/main         41kB
#   + nettle                      3.7.3  hbbd107a_1      pkgs/main        829kB
#   + libbrotlienc                1.0.9  h5eee18b_8      pkgs/main        293kB
#   + libbrotlidec                1.0.9  h5eee18b_8      pkgs/main         32kB
#   + libidn2                     2.3.4  h5eee18b_0      pkgs/main        149kB
#   + pydantic-core              2.20.1  py38hb02cf49_0  pkgs/main          2MB
#   + annotated-types             0.6.0  py38h06a4308_0  pkgs/main         23kB
#   + brotli-bin                  1.0.9  h5eee18b_8      pkgs/main         19kB
#   + gnutls                     3.6.15  he1e5248_0      pkgs/main          1MB
#   + pydantic                    2.8.2  py38h06a4308_0  pkgs/main        609kB
#   + brotli                      1.0.9  h5eee18b_8      pkgs/main         19kB
#   + inflect                     7.0.0  py38h06a4308_0  pkgs/main         63kB
#   + fonttools                  4.51.0  py38h5eee18b_0  pkgs/main          2MB
#   + libzlib                    1.2.13  h4ab18f5_6      conda-forge       62kB
#   + soxr                        0.1.3  h0b41bf4_3      conda-forge      131kB
#   + mpg123                     1.32.9  hc50e24c_0      conda-forge      491kB
#   + gettext-tools              0.22.5  he02047a_3      conda-forge        3MB
#   + libasprintf                0.22.5  he8f35ee_3      conda-forge       43kB
#   + libgettextpo               0.22.5  he02047a_3      conda-forge      171kB
#   + libasprintf-devel          0.22.5  he8f35ee_3      conda-forge       34kB
#   + libgettextpo-devel         0.22.5  he02047a_3      conda-forge       37kB
#   + gettext                    0.22.5  he02047a_3      conda-forge      479kB
#   + libflac                     1.4.3  h59595ed_0      conda-forge      394kB
#   + libsndfile                  1.2.2  hc60ed4a_1      conda-forge      354kB
#   + decorator                   5.1.1  pyhd3eb1b0_0    pkgs/main         12kB
#   + cycler                     0.11.0  pyhd3eb1b0_0    pkgs/main         13kB
#   + six                        1.16.0  pyhd3eb1b0_1    pkgs/main         19kB
#   + libtiff                     4.5.1  h6a678d5_0      pkgs/main        546kB
#   + libpng                     1.6.39  h5eee18b_0      pkgs/main        311kB
#   + intel-openmp             2023.1.0  hdb19cb5_46306  pkgs/main         18MB
#   + libllvm14                  14.0.6  hecde1de_4      pkgs/main         35MB
#   + python-dateutil        2.9.0post0  py38h06a4308_2  pkgs/main        286kB
#   + lcms2                        2.12  h3be6417_0      pkgs/main        319kB
#   + openjpeg                    2.5.2  he7f1fd0_0      pkgs/main        380kB
#   + freetype                   2.12.1  h4a9f257_0      pkgs/main        641kB
#   + mkl                      2023.1.0  h213fc3f_46344  pkgs/main        180MB
#   + pillow                     10.4.0  py38h5eee18b_0  pkgs/main        814kB
#   + mkl-service                 2.4.0  py38h5eee18b_1  pkgs/main         55kB
#   + numpy-base                 1.24.3  py38h060ed82_1  pkgs/main          7MB
#   + numpy                      1.24.3  py38hf6e8229_1  pkgs/main         11kB
#   + mkl_fft                     1.3.8  py38h5eee18b_0  pkgs/main        226kB
#   + mkl_random                  1.2.4  py38hdb19cb5_0  pkgs/main        335kB
#   + contourpy                   1.0.5  py38hdb19cb5_0  pkgs/main        208kB
#   + scipy                      1.10.1  py38hf6e8229_1  pkgs/main         23MB
#   + matplotlib-base             3.7.2  py38h1128e8f_0  pkgs/main          7MB
#   + scikit-learn                1.3.0  py38h1128e8f_1  pkgs/main          9MB
#   + llvmlite                   0.41.1  py38h94a1851_0  conda-forge        3MB
#   + soxr-python                 0.3.7  py38h7f0c24c_0  conda-forge      274kB
#   + numba                      0.58.1  py38h4144172_0  conda-forge        4MB
#   + ffmpeg                        4.3  hf484d3e_0      pytorch           10MB
#   + pytorch                    1.13.1  py3.8_cpu_0     pytorch           86MB
#   + pysoundfile                0.12.1  pyhd8ed1ab_0    conda-forge       28kB
#   + audioread                   3.0.1  py38h578d9bd_1  conda-forge       37kB
#   + librosa              0.10.2.post1  pyhd8ed1ab_0    conda-forge      198kB
#
#   Change:
# ───────────────────────────────────────────────────────────────────────────────
#
#   - zlib                       1.2.13  h5eee18b_1      pkgs/main       Cached
#   + zlib                       1.2.13  h4ab18f5_6      conda-forge       93kB
#
#   Summary:
#
#   Install: 86 packages
#   Change: 1 packages
#
#   Total download: 410MB
#
# ───────────────────────────────────────────────────────────────────────────────
#
#
#
# Looking for: ["pytorch[version='>=1.12.1,<2']", "numpy[version='>=1.22.0']", "scipy[version='>=1.4.1']", "librosa[version='>=0.10.0']", "inflect[version='>=0.2.5']", "numba[version='>=0.54.0']", 'pysoundfile==0.12.1', 'unidecode', 'tqdm']
#
#
# Pinned packages:
#   - python 3.8.*
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# /usr/local/lib/python3.8/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /usr/local/lib/python3.8/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# /usr/local/lib/python3.8/site-packages/conda/base/context.py:198: FutureWarning: Adding 'defaults' to channel list implicitly is deprecated and will be removed in 25.3.
#
# To remove this warning, please choose a default channel explicitly with conda's regular configuration system, e.g. by adding 'defaults' to the list of channels:
#
#   conda config --add channels defaults
#
# For more information see https://docs.conda.io/projects/conda/en/stable/user-guide/configuration/use-condarc.html
#
#   deprecated.topic(
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header

# %%
# !conda --version
# !which conda
# !python --version
# !which python
# Out:
# conda 24.7.1
# /usr/local/bin/conda
# Python 3.8.20
# /usr/local/bin/python

# %%
import sys
_ = (sys.path.append("/usr/local/bin/python3.8/site-packages"))
_ = (sys.path.append("/usr/local/bin/python3.8"))
_ = (sys.path.append("/usr/local/bin/python3.8/dist-packages"))

sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/usr/local/lib/python3.10/dist-packages/setuptools/_vendor',
#  '/root/.ipython',
#  '/usr/local/bin/python3.8/site-packages',
#  '/usr/local/bin/python3.8',
#  '/usr/local/bin/python3.8/dist-packages']

# %%
# Install dependencies
# !pip install "torch>=1.12.1,<2"
# !pip install "numpy>=1.22.0"
# !pip install "scipy>=1.4.1"
# !pip install "librosa>=0.10.0"
# !pip install "inflect>=0.2.5"
# !pip install "numba>=0.48.0"
# !pip install "soundfile==0.12.1"
# !pip install "tqdm"
# dataset.py
import os

import librosa
import numpy as np
from torch.utils.data import Dataset

max_time_steps = 16000
upsample_conditional_features = True
hop_length = 256

class HW5Dataset(Dataset):
    def __init__(self, meta):
        self.meta = os.path.realpath(meta)
        self.paths, self.labels = self.collect_files()

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, idx):
        """When iterating through the dataset, the first returned value
        is the original wav file, the second is the mel spectrogram, and
        the third is the label.
        e.g. wav, mel_spectrogram, label = next(iter(val_dataset))
        """
        wav, sr = librosa.load(self.paths[idx], sr=22050)

        wav = wav / np.abs(wav).max() * 0.999
        n_fft = 1024
        hop_length = 256

        mel_spectrogram = librosa.feature.melspectrogram(
            y=wav, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=8,
            fmin=125, fmax=7600).T

        mel_spectrogram = torch.tensor(mel_spectrogram)
        label = torch.FloatTensor([self.labels[idx]]).long()
        return mel_spectrogram, label

    def collect_files(self):
        paths = []
        labels = []
        with open(self.meta, "r") as f:
            for line in f:
                file, label = line.strip().split(',')
                paths.append(os.path.realpath(file))
                labels.append(float(label))

        return paths, labels
# Out:
# Requirement already satisfied: torch<2,>=1.12.1 in /usr/local/lib/python3.8/site-packages (1.13.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.8/site-packages (from torch<2,>=1.12.1) (4.11.0)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.8/site-packages (1.24.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.8/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.8/site-packages (from scipy>=1.4.1) (1.24.3)
# Requirement already satisfied: librosa>=0.10.0 in /usr/local/lib/python3.8/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.7.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.8/site-packages (from librosa>=0.10.0) (1.0.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/site-packages (from lazy-loader>=0.1->librosa>=0.10.0) (24.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.8/site-packages (from numba>=0.51.0->librosa>=0.10.0) (0.41.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/site-packages (from numba>=0.51.0->librosa>=0.10.0) (7.0.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.8/site-packages (from pooch>=1.1->librosa>=0.10.0) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/site-packages (from pooch>=1.1->librosa>=0.10.0) (2.32.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa>=0.10.0) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/site-packages (from soundfile>=0.12.1->librosa>=0.10.0) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa>=0.10.0) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests>=2.19.0->pooch>=1.1->librosa>=0.10.0) (2024.8.30)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa>=0.10.0) (3.20.2)
# Requirement already satisfied: inflect>=0.2.5 in /usr/local/lib/python3.8/site-packages (7.0.0)
# Requirement already satisfied: pydantic>=1.9.1 in /usr/local/lib/python3.8/site-packages (from inflect>=0.2.5) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/site-packages (from inflect>=0.2.5) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.8/site-packages (from pydantic>=1.9.1->inflect>=0.2.5) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.8/site-packages (from pydantic>=1.9.1->inflect>=0.2.5) (2.20.1)
# Requirement already satisfied: numba>=0.48.0 in /usr/local/lib/python3.8/site-packages (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.8/site-packages (from numba>=0.48.0) (0.41.1)
# Requirement already satisfied: numpy<1.27,>=1.22 in /usr/local/lib/python3.8/site-packages (from numba>=0.48.0) (1.24.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/site-packages (from numba>=0.48.0) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/site-packages (from importlib-metadata->numba>=0.48.0) (3.20.2)
# Requirement already satisfied: soundfile==0.12.1 in /usr/local/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.8/site-packages (from soundfile==0.12.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/site-packages (from cffi>=1.0->soundfile==0.12.1) (2.21)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/site-packages (4.66.5)

# %%
# model.py
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import auc, roc_curve
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from tqdm import tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau


class HW5Model(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        self.setup_model(**kwargs)

    def setup_model(
            self,
            input_size: int = 8,
            hidden_size: int = 16,
            num_layers: int = 2,
            lr: float = 1e-3,
            device: torch.device = torch.device('cpu')
            ) -> None:
        """Setup model architecture here. To improve the performance of
        the model, You can try different hyperparameters here, or change
        the network architecture. Note that the forward function might
        not be compatible with the new architecture.

        Parameters
        ----------
        input_size: int
            input size of the LSTM network.

        hidden_size: int
            hidden size of the LSTM network.

        num_layers: int
            number of layers of the LSTM network.

        lr: float
            learning rate of the optimizer.

        device: torch.device
            context-manager that changes the selected device.
        """
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.output_layer = nn.Linear(hidden_size, 1)
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)
        self.device = device
        self.weight_for_positives = torch.tensor([[400/600]]).to(self.device)
        self.loss = torch.nn.BCEWithLogitsLoss(pos_weight=self.weight_for_positives)
        self.optimizer = torch.optim.Adam(self.parameters(), lr=lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, patience=2, factor=0.5)

        self.to(device)
        return

    def forward(self, batch: torch.Tensor) -> torch.Tensor:
        """Forward pass.

        Parameters
        ----------
        batch: torch.Tensor
            input tensor of shape (batch_size, n_time_steps, input_size).

        Returns
        -------
        torch.Tensor:
            output tensor of shape (batch_size,).
        """
        embed, _ = self.lstm(batch)
        embed = torch.mean(embed, dim=1)
        output = self.output_layer(embed)
        output = torch.squeeze(output)
        return output

    def train_epochs(
            self,
            train_loader: DataLoader,
            val_loader: DataLoader,
            patience: int = 5,
            max_n_epochs: int = 15) -> None:
        """Train the model with max number of epochs. You should finish the TODOs in this function.

        Parameters
        ----------
        train_loader: torch.utils.data.DataLoader
            dataloader for training data.

        val_loader: torch.utils.data.DataLoader
            dataloader for validation data.

        patience: int
            number of epochs to wait before early stop, default to 5.

        max_n_epochs: int
            maximum number of epochs to train, default to 10.
        """



        # initialize the best loss  (used for early stopping)
        best_loss = np.inf
        early_stop_counter = patience


        for epoch in range(max_n_epochs):
            current_lr = self.optimizer.param_groups[0]['lr']
            print(f'Current Learning Rate: {current_lr}')
            self.train()
            train_loss_logs = []
            for (mels, labels) in tqdm(train_loader):
                mels = mels.to(self.device)
                labels = labels.to(self.device)
                # TODO (5P): change the following, make forward pass, and save the result to y_pred.
                # CHECK: self.forward
                # CHECK: https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#pytorch-optim
                y_pred = self.forward(mels)

                # TODO (5P): change the following, compute loss and perform back propagation.
                # CHECK: self.loss
                # CHECK: https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html
                # CHECK: https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#pytorch-optim
                y_pred = y_pred.unsqueeze(0)
                labels = labels.unsqueeze(0)

                # print(y_pred.shape)
                # labels = labels.view_as(y_pred)
                # print(labels.shape)

                train_loss = self.loss(y_pred, labels.float())

                train_loss_logs.append(train_loss.item())

                # TODO (5P): update the weights of the network through gradient descent.
                # CHECK: self.optimizer
                # CHECK: https://pytorch.org/docs/stable/optim.html
                # CHECK: https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#pytorch-optim
                self.optimizer.zero_grad()
                train_loss.backward()
                self.optimizer.step()


                # log training loss
                train_loss_logs.append(train_loss.item())

            # take the average of training loss
            average_train_loss = np.mean(np.array(train_loss_logs))

            self.eval()
            val_loss_logs = []
            with torch.no_grad():
              for mels, labels in tqdm(val_loader):
                  mels = mels.to(self.device)
                  labels = labels.to(self.device)
                  # TODO (5P): change the following, make forward pass, and save the result to y_pred.
                  # CHECK: self.forward
                  # CHECK: https://pytorch.org/tutorials/beginner/pytorch_with_examples.html#pytorch-optim
                  y_pred = self.forward(mels)


                  # TODO (5P): change the following, compute loss.
                  # CHECK: self.loss
                  # CHECK: https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html
                  y_pred = y_pred.unsqueeze(0)
                  labels = labels.unsqueeze(0)
                  val_loss = self.loss(y_pred, labels.float())
                  val_loss_logs.append(val_loss.item())

                  # log validation loss
                  val_loss_logs.append(val_loss.item())

            # take the average of validation loss
            average_val_loss = np.mean(np.array(val_loss_logs))
            self.scheduler.step(average_val_loss)

            print(f'{epoch+1:03}\ttrain_loss: {average_train_loss:.2f}\tval_loss: {average_val_loss:.2f}')

            if average_val_loss < best_loss:
               # TODO (5P): implement early stopping here, if the validation loss is smaller than the
               # current best. Save the model, update the best loss and reset the early stop counter.
               # CHECK: https://pytorch.org/tutorials/beginner/saving_loading_models.html#save-load-state-dict-recommended
               # Please name the model’s state_dict as best_model.ckpt)
               best_loss = average_val_loss
               early_stop_counter = patience
               torch.save(self.state_dict(), 'best_model.ckpt')
            else:
               early_stop_counter -= 1
               if early_stop_counter == 0:
                  print("Early stopping triggered")
                  break

        return

    def predict_prob(self, dataloader: torch.utils.data.DataLoader) -> np.array:
        """Predict the probability of the audio class based on trained.
        the output should be of shape (n_samples,). Each element is the
        predicted probability for the sample being AI generated recoding.

        Parameters
        ----------
        data_loader: torch.utils.data.DataLoader
            dataloader to be predicted.

        Returns
        -------
        np.array:
            the output should be of shape (n_samples,). Each element is the
            predicted probability for the sample being AI generated recoding.
            e.g. np.array([0.03111489, 0.6505939 , 0.16935825, ...], dypte=np.float32)
        """
        self.eval()
        probs = []
        with torch.no_grad():
          for (mels, labels) in tqdm(dataloader):
              # TODO (10P): change this. The model only predict the
              # logits of the probability of AI generated recording. You
              # need to compute the probability of both real recording and
              # AI generated recording.
              # CHECK: https://pytorch.org/docs/stable/generated/torch.nn.Sigmoid.html
              mels = mels.to(self.device)
              logits = self.forward(mels)
              probs.append(torch.sigmoid(logits).cpu().numpy())  # Convert logits to probabilities

        probs_np = np.concatenate(probs)
        return probs_np

    def predict(self, dataloader: torch.utils.data.DataLoader) -> np.array:
        """Predict the output based on trained model, the output should
        be of shape (n_samples,). Output 0 for the sample if the model
        predict the sample to be real recording, 1 otherwise.

        Parameters
        ----------
        data_loader: torch.utils.data.DataLoader
            dataloader to be predicted.

        Returns
        -------
        np.array:
            output 0 for the sample if the model predict the sample to
            be real recording, 1 otherwise.
            e.g. np.array([0, 1, 0], dypte=np.float32)
        """
        # TODO (10P): change this, it would be easier to implement
        # `predict_prob` first, and start from the output of it.
        probabilities = self.predict_prob(dataloader)
        predictions = np.where(probabilities > 0.5, 1, 0)  # Threshold at 0.5
        return predictions


    def evaluate(self, y_true: np.array, y_prob: np.array) -> float:
        """Evaluate the output based on the ground truth, the output
        should be the area under precision recall curve.

        Parameters
        ----------
        y_true: np.array
            the ground truth of the data.

        y_pred: np.array
            the output of model.predict_prob.

        Returns
        -------
        float:
            the area under precision recall curve.
        """
        # TODO (10P): return value should be the AUROC given y_true and y_prob, and you need to plot the ROC curve.
        # CHECK: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html
        # CHECK: https://scikit-learn.org/stable/modules/generated/sklearn.metrics.auc.html

        # Compute ROC curve and AUROC
        fpr, tpr, thresholds = roc_curve(y_true, y_prob)
        auroc = auc(fpr, tpr)

        # Plot ROC curve
        plt.figure()
        plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auroc)
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic')
        plt.legend(loc="lower right")
        plt.show()

        return auroc

# %%
# main.py
from torch.nn.utils.rnn import pad_sequence

def collate_batch(batch):
  mels, labels = zip(*batch)
  # Pad the mel pectrogram to make them have the same length
  mels = pad_sequence(mels, batch_first=True)
  return mels, torch.FloatTensor(labels)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Add the audio you generated to the training data. Remember to modify the meta.csv, and all the generated data should be label as 1 (generated from AI)
# !find /content/drive/MyDrive/generate_audio/ -name "*flowavenet*" -exec cp {} /content/train_dataset/wavs/ \;
# %cd /content/
# !find train_dataset -name "*flowavenet*wav" -exec echo {},1 \; >> /content/train_dataset/meta.csv
# Out:
# Mounted at /content/drive
# /content

# %%
# main.py
import torch
from torch.utils.data import DataLoader

RANDOM_STATE = 2023
dataset = HW5Dataset('train_dataset/meta.csv')
random_seed_generator = torch.Generator().manual_seed(RANDOM_STATE)

# TODO (5P): Create training and validation dataset based on `dataset`
# and `random_seed_generator`. You should split the dataset into 80%
# samples for the training, and 20% samples for the validation. You
# should use `random_seed_generator` to ensure consistency of the
# result.
# CHECK: https://pytorch.org/docs/stable/data.html#torch.utils.data.random_split

total_size = len(dataset)
print(total_size)

train_size = int(0.8 * total_size)  # 80% of the total size
val_size = total_size - train_size  # Remaining 20% for validation

train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size], generator=random_seed_generator)

# TODO (5P): Create training and validation data loader based on
# `train_dataset` and `val_dataset`. For val_loader, please set
# `shuffle=False` for the consistency of the result.
# CHECK: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#preparing-your-data-for-training-with-dataloaders
# e.g. train_loader = DataLoader(..., collate_fn=collate_batch)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, collate_fn=collate_batch)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, collate_fn=collate_batch)


# Optional: change different hyperparameters, to get the best model.
hidden_size = 16
num_layers = 4
lr = 8e-3
patience = 5
max_n_epochs = 30

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

model = HW5Model(hidden_size=hidden_size, num_layers=num_layers, lr=lr, device=device)
model.train_epochs(train_loader, val_loader, patience=patience, max_n_epochs=max_n_epochs)
# Out:
# 522
# Device: cpu
# Current Learning Rate: 0.008
# 100%|██████████| 7/7 [00:31<00:00,  4.44s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
# 001	train_loss: 0.49	val_loss: 0.40
# Current Learning Rate: 0.008
# 100%|██████████| 7/7 [00:10<00:00,  1.43s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 002	train_loss: 0.43	val_loss: 0.39
# Current Learning Rate: 0.008
# 100%|██████████| 7/7 [00:11<00:00,  1.59s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# 003	train_loss: 0.43	val_loss: 0.40
# Current Learning Rate: 0.008
# 100%|██████████| 7/7 [00:11<00:00,  1.65s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# 004	train_loss: 0.42	val_loss: 0.40
# Current Learning Rate: 0.008
# 100%|██████████| 7/7 [00:10<00:00,  1.44s/it]
# 100%|██████████| 2/2 [00:03<00:00,  1.53s/it]
# 005	train_loss: 0.43	val_loss: 0.40
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:08<00:00,  1.25s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# 006	train_loss: 0.43	val_loss: 0.39
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:10<00:00,  1.57s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.19it/s]
# 007	train_loss: 0.43	val_loss: 0.39
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:12<00:00,  1.75s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# 008	train_loss: 0.42	val_loss: 0.39
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:11<00:00,  1.59s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# 009	train_loss: 0.42	val_loss: 0.39
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:09<00:00,  1.30s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.50s/it]
# 010	train_loss: 0.41	val_loss: 0.38
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:09<00:00,  1.36s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# 011	train_loss: 0.39	val_loss: 0.36
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:11<00:00,  1.60s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 012	train_loss: 0.38	val_loss: 0.32
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:11<00:00,  1.59s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 013	train_loss: 0.35	val_loss: 0.29
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:10<00:00,  1.48s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# 014	train_loss: 0.36	val_loss: 0.29
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:08<00:00,  1.25s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# 015	train_loss: 0.38	val_loss: 0.35
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:10<00:00,  1.48s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 016	train_loss: 0.37	val_loss: 0.35
# Current Learning Rate: 0.004
# 100%|██████████| 7/7 [00:11<00:00,  1.61s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# 017	train_loss: 0.38	val_loss: 0.35
# Current Learning Rate: 0.002
# 100%|██████████| 7/7 [00:11<00:00,  1.62s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 018	train_loss: 0.37	val_loss: 0.31
# Current Learning Rate: 0.002
# 100%|██████████| 7/7 [00:09<00:00,  1.41s/it]
# 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# 019	train_loss: 0.36	val_loss: 0.32
# Early stopping triggered

# %%
# Load your best model and plot the ROC curve of validation data
# Remeber to download .png file and submit with your code
model.load_state_dict(torch.load("best_model.ckpt"))
y_pred_prob = model.predict_prob(val_loader)
y_pred = model.predict(val_loader)
y_true = torch.concat([labels for mel, labels in val_loader]).numpy().astype('float32')
print(f'Accuracy on validation set: {(y_pred == y_true).sum() / len(y_true):.2f}')
print(f'Area under precision recall curve on validation set: {model.evaluate(y_true, y_pred_prob):.2f}')
# Out:
# <ipython-input-13-2b9dda246557>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_model.ckpt"))
# 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.18it/s]
# Accuracy on validation set: 0.78
# Area under precision recall curve on validation set: 0.82

# %%
from google.colab import files
# Download the parameters of the best model
files.download('./best_model.ckpt')

# %%
## TA will evaluate you model as follows
'''
test_dataset = HW5Dataset('../test_dataset/meta.csv')
test_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, collate_fn=collate_batch)

model = HW5Model(hidden_size=hidden_size, num_layers=num_layers)

# If you directly clone the github repo
model.load_state_dict(torch.load("best_model.ckpt"))
# # If you use colab and submit the .ipynb
# model.load_state_dict(torch.load("/content/best_model.ckpt"))

y_pred_prob = model.predict_prob(test_loader)
y_pred = model.predict(test_loader)
y_true = torch.concat([labels for mel, labels in val_loader]).numpy().astype('float32')
print(f'Accuracy on test set: {(y_pred == y_true).sum() / len(y_true):.2f}')
print(f'Area under precision recall curve on test set: {model.evaluate(y_true, y_pred_prob):.2f}')
f1 = f1_score(y_true, y_pred, average='binary')  # Adjust 'average' for multi-class if needed
print(f'F1 Score on test set: {f1:.2f}')

'''
# Out:
# '\ntest_dataset = HW5Dataset(\'../test_dataset/meta.csv\')\ntest_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, collate_fn=collate_batch)\n\nmodel = HW5Model(hidden_size=hidden_size, num_layers=num_layers)\n\n# If you directly clone the github repo\nmodel.load_state_dict(torch.load("best_model.ckpt"))\n# # If you use colab and submit the .ipynb\n# model.load_state_dict(torch.load("/content/best_model.ckpt"))\n\ny_pred_prob = model.predict_prob(test_loader)\ny_pred = model.predict(test_loader)\ny_true = torch.concat([labels for mel, labels in val_loader]).numpy().astype(\'float32\')\nprint(f\'Accuracy on test set: {(y_pred == y_true).sum() / len(y_true):.2f}\')\nprint(f\'Area under precision recall curve on test set: {model.evaluate(y_true, y_pred_prob):.2f}\')\nf1 = f1_score(y_true, y_pred, average=\'binary\')  # Adjust \'average\' for multi-class if needed\nprint(f\'F1 Score on test set: {f1:.2f}\')\n\n'
